# %%
import numpy as np
import h5py
f = h5py.File('/Users/samundrakarki/Downloads/Aditya_data/combustion_img_13.mat','r')
train_x = f.get("train_set_x")
train_x.shape
# Out:
# (25000, 54000)

# %% [markdown]
# RESHAPE THE DATA TO CHANGE IMAGE INTO ROWS

# %%
data = np.array(train_x)

# %%
data_transpose = data.T

# %%
data_transpose.shape
# Out:
# (54000, 25000)

# %%
import matplotlib.pyplot as plt
from matplotlib import axes

# %%
def plot_random(data_array,cols=5,rows=5):
    num_images = data_array.shape[0]
    fig,axes = plt.subplots(rows,cols,figsize=(20,20))
    random_choices = np.random.choice(num_images,cols*rows)

    for i in range(rows):
        for j in range(cols):
            axes[i][j].imshow(data_array[random_choices[(i+1)*(j+1)-1]].reshape(250,100))

    plt.show()

# %%
plot_random(data_transpose)

# %%
train_y = f.get("train_set_y")
train_y.shape
# Out:
# (54000, 1)

# %%
import pandas as pd

# %%
df = pd.DataFrame(np.array(train_y),columns=["Stability"])
df.head()
# Out:
#    Stability
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
df.value_counts()
# Out:
# Stability
# 0            30000
# 1            24000
# dtype: int64

# %%
import seaborn as sns

# %%
# Plot count plot
ax = sns.countplot(x="Stability", data=df)

# %% [markdown]
# THE DATA IS BALANCED

# %%
df.Stability.value_counts()[1]/df.Stability.value_counts()[0]*100
# Out:
# 80.0
